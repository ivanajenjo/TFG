# %%
import pandas as pd
import select_features
#archivo = '..\data\ISBSG - Release May 2017 R1.csv'
archivo = '..\data\ISBSG DATA Release 12.csv'
df = pd.read_csv(archivo, sep = ';', low_memory = False)
#variables = ['Data Quality Rating', 'UFP rating', 'Industry Sector','Application Group', 'Development Type', 'Development Platform', 'Language Type', 'Primary Programming Language', 'Count Approach', 'Functional Size', 'Adjusted Function Points', 'Normalised Work Effort Level 1', 'Summary Work Effort', 'Project Elapsed Time', 'Business Area Type', '1st Data Base System', 'Used Methodology', 'Resource Level', 'Max Team Size', 'Average Team Size', 'Input count', 'Output count', 'Enquiry count', 'File count', 'Interface count', 'Agile Method Used']
df.columns
# Out:
# Index(['ISBSG Project ID', 'Data Quality Rating', 'UFP rating',
#        'Year of Project', 'Industry Sector', 'Organisation Type',
#        'Application Group', 'Application Type', 'Development Type',
#        'Development Platform',
#        ...
#        'Added count', 'Changed count', 'Deleted count', 'COSMIC Entry',
#        'COSMIC Exit', 'COSMIC Read', 'COSMIC Write', 'Lines of Code',
#        'Lines of Code not Statements', 'Other Size Units'],
#       dtype='object', length=126)

# %%
variables = ['Data Quality Rating', 'UFP rating', 'Industry Sector','Application Group', 'Development Type', 'Development Platform', 'Language Type', 'Primary Programming Language', 'Count Approach', 'Functional Size', 'Adjusted Function Points', 'Normalised Work Effort Level 1', 'Summary Work Effort', 'Project Elapsed Time', 'Business Area Type', '1st Data Base System', 'Used Methodology', 'Resource Level', 'Max Team Size', 'Average Team Size', 'Input count', 'Output count', 'Enquiry count', 'File count', 'Interface count']
df = df.loc[:,variables]
df
# Out:
#      Data Quality Rating UFP rating     Industry Sector     Application Group  \
# 0                      D          A    Service Industry  Business Application
# 1                      B          A        Construction  Business Application
# 2                      B          A  Wholesale & Retail  Business Application
# 3                      B          A                 NaN                   NaN
# 4                      B          A  Wholesale & Retail  Business Application
# ...                  ...        ...                 ...                   ...
# 6001                   B          B          Government  Business Application
# 6002                   B          A                 NaN                   NaN
# 6003                   B          A          Government  Business Application
# 6004                   A        NaN          Government  Business Application
# 6005                   B          B       Manufacturing  Business Application
#
#      Development Type Development Platform Language Type  \
# 0     New Development                   MR           4GL
# 1     New Development                Multi           4GL
# 2         Enhancement                  NaN           3GL
# 3         Enhancement                  NaN           NaN
# 4         Enhancement                   MF           3GL
# ...               ...                  ...           ...
# 6001      Enhancement                   MF           3GL
# 6002  New Development                  NaN           NaN
# 6003      Enhancement                   MF           3GL
# 6004  New Development                   PC           3GL
# 6005      Enhancement                Multi           3GL
#
#      Primary Programming Language Count Approach  Functional Size  ...  \
# 0                          Oracle          NESMA            237.0  ...
# 1                          Access       IFPUG 4+            443.0  ...
# 2                           COBOL       IFPUG 4+             76.0  ...
# 3                             NaN       IFPUG 4+              3.0  ...
# 4                           COBOL       IFPUG 4+            382.0  ...
# ...                           ...            ...              ...  ...
# 6001                        COBOL       IFPUG 4+             23.0  ...
# 6002                          NaN       IFPUG 4+            291.0  ...
# 6003                        COBOL       IFPUG 4+            119.0  ...
# 6004                            C         COSMIC             45.0  ...
# 6005                         Java       IFPUG 4+             95.0  ...
#
#          1st Data Base System  Used Methodology  Resource Level Max Team Size  \
# 0                     Oracle;                No             1.0             5
# 1                     ACCESS;        Don't Know             1.0           NaN
# 2                         NaN               Yes             1.0           NaN
# 3                         NaN               NaN             1.0           NaN
# 4                Interactive;               Yes             4.0           NaN
# ...                       ...               ...             ...           ...
# 6001                      NaN               Yes             1.0           NaN
# 6002                      NaN        Don't Know             1.0             3
# 6003                    IDMS;               Yes             4.0           NaN
# 6004  SYBASE Adaptive Server;               Yes             4.0             3
# 6005                  Oracle;               Yes             3.0           NaN
#
#      Average Team Size Input count Output count  Enquiry count File count  \
# 0                    5          60          110           10.0         42
# 1                  NaN         NaN          NaN            NaN        NaN
# 2                  NaN         NaN          NaN            NaN        NaN
# 3                  NaN         NaN          NaN            NaN        NaN
# 4                  NaN         186            7          172.0          7
# ...                ...         ...          ...            ...        ...
# 6001               NaN         NaN          NaN            NaN        NaN
# 6002               1,7         NaN          NaN            NaN        NaN
# 6003               NaN          18           46           18.0          7
# 6004               1,8         NaN          NaN            NaN        NaN
# 6005               NaN         NaN          NaN            NaN        NaN
#
#      Interface count
# 0               15.0
# 1                NaN
# 2                NaN
# 3                NaN
# 4               10.0
# ...              ...
# 6001             NaN
# 6002             NaN
# 6003            30.0
# 6004             NaN
# 6005             NaN
#
# [6006 rows x 25 columns]

# %%
filtro = ((df['Data Quality Rating'] == 'A') | (df['Data Quality Rating'] == 'B')) & ((df['UFP rating'] == 'A') | (df['UFP rating'] == 'B')) 
df = df.loc[filtro, :]
filtro = (df['Normalised Work Effort Level 1'].notnull()) & (df['Normalised Work Effort Level 1'] == df['Summary Work Effort'])
df = df.loc[filtro, :]
filtro = df['Count Approach'] == 'IFPUG 4+'
df = df.loc[filtro, :]
variables = ['Industry Sector','Application Group', 'Development Type', 'Development Platform', 'Language Type', 'Primary Programming Language', 'Functional Size', 'Adjusted Function Points', 'Normalised Work Effort Level 1', 'Project Elapsed Time', 'Business Area Type', '1st Data Base System', 'Used Methodology', 'Max Team Size', 'Average Team Size', 'Input count', 'Output count', 'Enquiry count', 'File count', 'Interface count']
df = df.loc[:,variables]
df = df.dropna(axis=1, thresh=int(0.5*len(df)))
df = df.dropna()
df
# Out:
#        Industry Sector     Application Group Development Type  \
# 5            Insurance  Business Application  New Development
# 33          Government  Business Application  New Development
# 54           Utilities  Business Application  New Development
# 90       Manufacturing  Business Application  New Development
# 106   Service Industry  Business Application  New Development
# ...                ...                   ...              ...
# 5954        Government  Business Application      Enhancement
# 5965         Financial  Business Application  New Development
# 5991         Financial  Business Application      Enhancement
# 5995        Government  Business Application      Enhancement
# 5998        Government  Business Application  New Development
#
#      Development Platform Language Type Primary Programming Language  \
# 5                      MF           3GL                         Java
# 33                     MF           3GL                        COBOL
# 54                     MF           3GL                         PL/I
# 90                  Multi           4GL                          SQL
# 106                    PC           3GL                           C#
# ...                   ...           ...                          ...
# 5954                   MF           3GL                        COBOL
# 5965                Multi           4GL                 PowerBuilder
# 5991                   MR           3GL                        COBOL
# 5995                   MF           3GL                         PL/I
# 5998                Multi           4GL                    Datastage
#
#       Functional Size  Adjusted Function Points  \
# 5               620.0                     620.0
# 33              243.0                     250.0
# 54              163.0                     152.0
# 90              702.0                     702.0
# 106              90.0                     101.0
# ...               ...                       ...
# 5954             12.0                      12.0
# 5965            478.0                     478.0
# 5991            242.0                     213.0
# 5995             96.0                      96.0
# 5998           1048.0                    1048.0
#
#       Normalised Work Effort Level 1 Project Elapsed Time  \
# 5                            18160.0                    7
# 33                            2924.0                    8
# 54                             668.0                    9
# 90                            4805.0                 12,3
# 106                           2006.0                    5
# ...                              ...                  ...
# 5954                           129.0                    3
# 5965                          2716.0                  5,8
# 5991                          2185.0                    7
# 5995                          1011.0                    6
# 5998                          7722.0                   16
#
#      1st Data Base System Used Methodology
# 5                IMS;DB2;       Don't Know
# 33                   DB2;              Yes
# 54                   DB2;              Yes
# 90     Oracle,SQL Server;       Don't Know
# 106   MS SQL Server 2005;              Yes
# ...                   ...              ...
# 5954                VSAM;              Yes
# 5965              Oracle;       Don't Know
# 5991                 RDB;               No
# 5995                 DB2;              Yes
# 5998                 DB2;              Yes
#
# [621 rows x 12 columns]
